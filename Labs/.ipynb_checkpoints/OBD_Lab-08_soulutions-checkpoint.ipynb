# %% [markdown]
# ## <center>  MATH11146: Modern Optimization Methods for Big Data Problems </center>
#
# <center> University of Edinburgh</center>
#
# <center>Lecturer: Peter Richtarik</center>
#
# <center>Tutors: Sona Galovicova, Filip Hanzely, Jakub Konecny</center>
#
# ##  <center>Lab 8: Empirical Risk Minimization</center>
# <center>(C) Dominik Csiba and Peter Richtarik </center>
# <center> 15.2.2017 </center>
#
#
# ## 1. Introduction
#
# The purpose of this lab is to fool around with an efficient randomized algorithm for <i>minimizing finite sums</i>. In particular, we will be solving the L2-regularized empirical risk minimization (ERM) problem, namely
#
# $$\min_{w\in \mathbb{R}^d} \left\{ P(w) \equiv \frac{1}{n}\sum_{i=1}^n \phi_i(X_i^T w) + \frac{\lambda}{2}\|w\|_2^2 \right\},$$
# using Dual-Free SDCA (dfSDCA) [1, 2].
#
# The meaning of the terms above:
# - $w\in \mathbb{R}^d$ is a linear predictor,
# - $X_1,\dots,X_n \in \mathbb{R}^{m\times d}$ are training examples (in this code we will assume that $m=1$ and hence the examples are simply just vectors),
# - $\phi_i:\mathbb{R}^d \to \mathbb{R}$ is the loss incurred on example $i$ (label associated with example $i$ is already incorporated in the definition of $\phi_i$; this why the function $\phi_i$ has a subscript),
# - $\lambda>0$ is a regularization parameter (typically, $\lambda=\frac{1}{n}$),
# - $P$ is the regularized empirical risk.
#
#
# $\textbf{Assumption 1.}$ The loss functions $\phi_i:\mathbb{R}^m\mapsto \mathbb{R}$, $i=1,\dots,n$, are $\tfrac{1}{\gamma}$-smooth. That is, for all $u,v\in \mathbb{R}^m$ the following inequality holds:
# $$\| \nabla \phi_i(u) - \nabla \phi_i(v) \|_2 \leq \frac{1}{\gamma}\|u-v\|_2.$$
# This is equivalent to requiring that for all $u,v\in \mathbb{R}^m$ one has
# $$ \phi_i(u+v) \leq \phi_i(u) + (\nabla \phi_i(u))^\top v + \frac{1}{2\gamma}\|v\|_2^2.$$
#
# $\textbf{Assumption 2.}$  The loss functions $\phi_i:\mathbb{R}^m \mapsto \mathbb{R}$, $i=1,\dots,n$, are convex. That is, for all $u,v\in \mathbb{R}^m$:
#
# $$\phi(u) + (\nabla \phi_i(u))^\top v \leq \phi_i(u+v).$$
#
# The standard SDCA (Stochastic Dual Coordinate Ascent) algorithm, as its name indicates, can be interreted as applying Stochastic/Randomized Coordinate Descent [3] to the Fenchel dual of the ERM problem. The dual problem is naturaly a concave maximization problem, and hence the word "ascent" is used instead of "descent". However, we have seen that dfSDCA is <i>not</i> motivated nor analyzed via the dual problem, and in this sense, the method is <i>dual-free</i>.
#
# - [1] S. Shalev-Shwartz. SDCA without duality, <i>arXiv:1502.06177</i>, 2015
# - [2] D. Csiba and P. Richtarik. Primal method for ERM with flexible mini-batching schemes and non-convex losses,
# <i>arXiv:1506.02227</i>, 2015
# - [3] P. Richtarik and M. Takac. Iteration complexity of randomized block-coordinate descent methods for minimizing a composite function, <i>Mathematical Programming</i> 144(2):1-38, 2014 (arXiv:1107.2848)

# %% [markdown]
# ## 2. Preliminary Stuff
#
# ### 2.1  Load a package for plotting
#
# We first load a package for plotting: <b>PyPlot</b>.
#
# ### 2.2  Load a package for sampling from a probability distribution
#
# We then include the  package <b>probability_tree.jl</b> with functions that will be useful for sampling from a non-uniform distribution from a finite set $[n]:=\{1, \dots, n\}$. In the lecture, we have considered <i>arbitrary samplings</i>, i.e., arbitrary set-valued mappings with values being the subsets of $[n]$. However, the package <b>probability_tree.jl</b> only implements samplings of  the form
#
# $$\mathbf{P}(S_t = \{i\}) = p_i,$$
#
# where $p_i>0$ for all $i\in [n]$ and $\sum_{i=1}^n p_i = 1$. In particular, the package <b>probability_tree.jl</b> contains two  routines:
# - <b>PTCreate</b> - with input being the weights $p$ and output being an array which we call a probability tree,
# - <b>PTSample</b> - with inpit being a probability tree and and output being a random integer $i$ with probability $p_i$.
#
# ### 2.3  Load a package for loading data from an external file
#
# Finally, the package <b>load_matricies.jl</b> contains two routines:
# - <b>ReadLIBSVM</b> - reads a dataset in LIBSVM format, inputs the filename, shape and a boolean <i>classification</i> indicating whether the dataset is for regression or classification, and outputs the matrix and labels
# - <b>ReadData</b> - reads a dataset in a standard format, inputs the filename and a boolean <i>classification</i> indicating whether the dataset is for regression or classification, and outputs the matrix and labels
#
# The data has to be stored in the folder "data".
#
# ### 2.4  Operator overloading
#
# We will also overload the $\cdot$ operator so that it outputs a scalar as a result of an inner product of a vecor represented as a sparse matrix and a vector represented as an array. These operations will be used often. The default type of the result, without the operator overloading, is a sparse matrix, which would be inconvenient.

# %%
using PyPlot

include("probability_tree.jl")

include("load_matrices.jl")

⋅(x::SparseMatrixCSC{Float64, Int64}, y::Array{Float64,1}) = (x'*y)[1]
⋅(x::SparseMatrixCSC{Float64, Int64}, y::SparseMatrixCSC{Float64, Int64}) = (x'*y)[1]
# Out:
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/salvadorgarcia/Repositories/UoE_2_OBD/Labs/load_matrices.jl:1
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/salvadorgarcia/Repositories/UoE_2_OBD/Labs/load_matrices.jl:55
# ⋅ (generic function with 2 methods)

# %% [markdown]
# ## 3. Loss Functions
#
# We assume that the $n$ examples $X_1,\dots,X_n \in \mathbb{R}^d$ are stored as columns of a $d\times n$ matrix $X$ (technically, a "sparse matrix" in Julia). We also assume that the associated labels $y_1,\dots,y_n\in \mathbb{R}$ are stored as entries of a vector  $y\in \mathbb{R}^n$ (technically, an "array" in Julia).
#
# In particular, we work with the quadratic loss:
#
# $$ \phi_i(t) = \frac{1}{2\gamma} (t - y_i)^2, \qquad  \nabla \phi_i(t) = \frac{1}{\gamma} (t-y_i), \qquad \phi_i(X_i^\top w) = \frac{1}{2\gamma} (X_{i}^\top w - y_i)^2, \qquad \nabla \phi_i(X_i^\top w) = \frac{1}{\gamma} (X_i^\top w - y_i).$$
#
# It can be verified that $\phi_i$ is indeed $\tfrac{1}{\gamma}$-smooth and convex.
#
# We now define a function <b>Loss_quadratic</b> whose output will be a touple:
# - function <b>P(w)</b>
# - function <b>g(w,i)</b> (which evaluates $\nabla \phi_i(X_i^\top w)$).
#
# Indeed, functions are first-class citizens in Julia. They can be an output of other functions. This is great, since it will allow us to write a single dfSDCA code which will call generic functions $P$ and $g$. Whenever we change these functions, the code runs with these new functions without any changes. This makes it easy to write flexible optimization code in Julia.
#
#
# ### Exercise A: Logistic Regression
#
# Replace the three ??? signs in the <b>Loss_logistic</b> function below by suitable code so that the  function works analogously to the <b>Loss_quadratic</b> function.
#
# <i> Hint: </i> The logistic loss is defined as
#
# $$ \phi_i(t) = \frac{4}{\gamma} \log \left(1 + e^{y_i t} \right)$$
#
# and its derivative is
#
# $$\nabla \phi_i(t) = \frac{4 y_i}{\gamma \left(1+ e^{-y_i t}\right)} \enspace .$$
#
# Again, it can be verified that $\phi_i$ is indeed $\tfrac{1}{\gamma}$-smooth and convex.

# %%
function Loss_quadratic(X::SparseMatrixCSC, y::Array{Float64,1}, γ::Float64, λ::Float64)
    n = size(X)[2]
    f(w, i) = 1/(2γ)*(X[:,i]⋅w - y[i])^2 # the overloading is used here
    g(w, i) = 1/γ*(X[:,i]⋅w - y[i]) # and here
    P(w)    = 1/n*sum([f(w,i) for i=1:n]) + λ/2*w⋅w
    return (g, P)
end

function Loss_logistic(X::SparseMatrixCSC, y::Array{Float64,1}, γ::Float64, λ::Float64)
    n = size(X)[2]
    f(w, i) = 4*log(1+exp(y[i]*X[:,i]⋅w))
    g(w, i) = 4*y[i]/(γ*(1+exp(-y[i]*X[:,i]⋅w)))
    P(w)    = 1/n*sum([f(w,i) for i=1:n]) + λ/2*w⋅w
    return(g, P)
end
# Out:
# Loss_logistic (generic function with 1 method)

# %% [markdown]
# ## 4. The dfSDCA Algorithm
#
# Recall that the dfSDCA algorithm looks as follows:
#
# Initialize:
# - Choose a sampling (random set-valued mapping) $\hat{S}$
# - Compute $p_i = \mathbf{P}(i \in \hat{S})$
# - Compute "stepsize" parameters $v_1,\dots,v_n$ satisfying the ESO inequality
# $$P \circ X^\top X \preceq Diag(p \circ v),$$
# where $v = (v_1,\dots,v_n)$, $p=(p_1,\dots,p_n)$ and $P$ is the $n\times n$ "probability" matrix associated with $\hat{S}$. That is, $P$ is the matrix with $(i,j)$ entry equal to $\mathbf{P}(\{i,j\}\subseteq \hat{S})$. Note that we are now using $P$ both for the probability matrix and the primal objective function. This is too bad, but then no confusion should be caused by this! This form of ESO only makes sense if $m=1$; for $m>1$, the correct ESO inequality looks a bit different [2].
# - Set
# $$\theta =  \min_{i}  \frac{p_i \lambda \gamma n}{v_i + \lambda \gamma n}$$
# - Choose initial "dual" variables $\alpha_1^{0}, \dots, \alpha_n^{0} \in \mathbb{R}^m$
# - Set
# $$w^{0} = \frac{1}{\lambda n}\sum_{i=1}^n X_i\alpha_i^{0}$$
#
# For $t \geq 0$ repeat:
# - Choose a random set (minibatch) $S_t\subseteq \{1,2,\dots,n\}$ of examples, with $S_t\sim \hat{S}$
# - For $i \in S_t$ do (possibly in parallel):
# $$\alpha_i^{t+1} = \left( 1- \frac{\theta}{p_i} \right) \alpha_i^{t} + \frac{\theta}{p_i}(-\nabla\phi_i(X_i^\top w^{t}))$$
# - Update the main variable:
# $$w^{t+1} = w^{t} - \sum_{i\in S_t} \frac{\theta}{\lambda n p_i}  X_i(\nabla\phi_i(X_i^\top w^{t}) + \alpha_i^{t})$$
#
#
# Now we write a Julia function called <b>dfSDCA</b> which implements the algorithm in the special case when $m=1$ and $|\hat{S}|=1$ with probability 1. It will have the following input variables:
# - $X$ = $d \times n$ data matrix
# - $g$ = function evaluating $\nabla\phi_i(X_i^\top w)$
# - $P$ = the objective function
# - $p$ = an array representing a discrete probability distribution over $\{1,2,\dots,n \}$
# - $T$ = number of iterations
# - $\gamma$ = smoothness parameter (we assume $\phi_i$ is $1/\gamma$-smooth)
# - $\lambda$ = strong-convexity parameter
# - <i>track</i> = a boolean deciding whether we want to output function values or the primal variable $w^{T}$
# - <i>AlgLabel</i> = label for the print outputs during the run of the algorithm
# - <i>progress</i> = a boolean value indicating whether the progress is shown in the console or not
#
# ### Exercise B
#
# There are 5 places with questions marks ??? in the dfSDCA code below. Replace them with the correct code.

# %%
function dfSDCA(X::SparseMatrixCSC, g::Function, P::Function, p::Array{Float64,1}, T::Int64, 
    γ::Float64, λ::Float64, track::Bool, AlgLabel::ASCIIString, progress::Bool)
    
(d,n) = size(X)
    
if track
        Pvalue = zeros(ifloor(T/n)+1) # prepares the array of function values
endf
     
v = convert(Array{Float64,1},[norm(X[:,i])^2 for i=1:n])

θ = minimum(p*λ*γ*n./(v + λ*γ*n)) # step size

PT = PTCreate(p) # creates the probability tree

α = zeros(n) # the starting points are set to zero vectors for simplicity
w = sum([X[:,i]*α[i] for i=1:n])/γ*n

for t=0:T

    if t % n == 0 # every n iterations store the function value and prints a message about progress
        if track
            Pvalue[t/n + 1] = P(w)
            if progress
                println(AlgLabel, ":  #passes $(t/n), function value: $(Pvalue[t/n + 1])")
            end
        else
            if progress
                println(AlgLabel, ":  #passes $(t/n)")
            end
        end
    end

    i = PTSample(PT) # sample a coordinate according to distribution p
    Δ = g(w,i) + α[i] # store the update as Δ
        α[i] -= θ/p[i] *(Δ)
        w -= (X[:,i]*θ*Δ) / (λ*n*p[i]) # vector - matrix = matrix
    w = vec(w) # matrix -> vector 
end

println( AlgLabel ," finished!" )

if track # return function values or w, dependig on track
    return Pvalue
else
    return w
end
    
end
# Out:
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:1
# dfSDCA (generic function with 1 method)

# %% [markdown]
# ## 5. Plotting Functions
#
# We now write 2 functions which will be used to visualize the results.
#
# Function <b>ShowConvergence</b> takes the following input:
# - <i>Pvalues</i> - a tuple of function value arrays
# - <i>AlgLabels</i> - a tuple of algorithm labels, for legend
# - <i>Pstar</i> - the optimal function value
#
# Function <b>dfSDCACompare</b> is used for comparing the behavior of several variants of <b>dfSDCA</b> in a single plot. The variants differ in the choice of the probability vector $p$. The function first finds the optimal function value (by running the <b>dfSDCA</b> method for 60 passes over data), and then uses the objective function value found in lieu of the true minimum. This is used in order to plot $P(w^t) - P(w^*)$  on the $y$ axis in logarithmic scale.
#
# Input:
#
# - $X$ = data matrix
# - $g$ = function evaluating $\phi_i(X_i^\top w)$
# - $P$ = the primal objective function
# - $T$ = number of iterations
# - $\gamma$ = smoothness parameter
# - $\lambda$ = strong-convexity parameter
# - $plist$ = a tuple of probability distributions
# - <i>AlgLabel</i> = tuple of labels for the print outputs during the run of the algorithm and for the legend
# - <i>progress</i> = a boolean indicating, whether the progress is shown in the console

# %%
function ShowConvergence(Pvalues, AlgLabels, Pstar::Float64)    
    ax = axes()
    for i=1:length(Pvalues)
        plt[:plot](0:(length(Pvalues[i])-1), abs(Pvalues[i]-Pstar), "-", linewidth=3.0, label=AlgLabels[i])
    end
    legend(loc="upper right")
    ylabel(L"$P(w^{t}) - P(w^\star)$", fontsize=20)
    xlabel("passes over data")
    ax[:set_yscale]("log")
    plt[:show]()
end

function dfSDCACompare(X::SparseMatrixCSC,  g::Function, P::Function, 
    T::Int64, γ::Float64, λ::Float64, plist, AlgLabel, progress::Bool)
    v = float([X[:,i]⋅X[:,i] for i=1:n])
    p_imp = v + λ*γ*n
    p_imp = p_imp/sum(p_imp)
    wstar = dfSDCA(X, g, P, p_imp, 2T, γ, λ, false, "Optimal value", progress)
    Pstar = P(wstar)
    Pvalues = [dfSDCA(X, g, P, plist[i], T, γ, λ, true, AlgLabel[i], progress) for i = 1:length(plist)]
    ShowConvergence(Pvalues, AlgLabel, Pstar)
end
# Out:
# WARNING: Method definition ShowConvergence(Any, Any, Float64) in module Main at In[4]:2 overwritten at In[5]:2.
# WARNING: Method definition dfSDCACompare(Base.SparseArrays.SparseMatrixCSC, Function, Function, Int64, Float64, Float64, Any, Any, Bool) in module Main at In[4]:15 overwritten at In[5]:15.
# dfSDCACompare (generic function with 1 method)

# %% [markdown]
# ## 6. Run the Method on a Problem with Synthetic Data

# %% [markdown]
# ### 6.1  We first generate a random problem

# %%
n = 1000
d = 100
X = sprand(d, n, 0.1)
y = rand(n)
γ = 1.0
λ = 1/n
A = X
g, P = Loss_quadratic(X,y,γ,λ)
# Out:
# (g,P)

# %% [markdown]
# ### 6.2  Now we define three different probability distributions
#
# These will correspond to three different versions of the dfSDCA method.

# %%
p1 = ones(n)/n
v = float([X[:,i]⋅X[:,i] for i=1:n]) # julia is having difficulties with arrays of type "Any"
p2 = v + n*λ*γ
p2 = p2/sum(p2)
p3 = 0.1 + rand(n)
p3 = p3/sum(p3)
# Out:
# MethodError: no method matching ⋅(::SparseVector{Float64,Int64}, ::SparseVector{Float64,Int64})
# you may have intended to import Base.⋅
#
#  in collect(::Base.Generator{UnitRange{Int64},##23#24}) at ./array.jl:307

# %% [markdown]
# ### 6.3  We can now run the method

# %%
dfSDCACompare(X, g, P, 30n, γ, λ, (p1,p2,p3), ("dfSDCA-unif", "dfSDCA-imp", "dfSDCA-rand"), false)
# Out:
# UndefVarError: p2 not defined

# %% [markdown]
# ## 7. Run the Method on a Problem with Real Data

# %%
X,y = ReadData("mushrooms", true)
#X,y = ReadLIBSVM("ijcnn1.tr", (49990,22) ,true)


d,n = size(X)
γ = 1.0
λ = 1/n
g, P = Loss_logistic(X,y,γ,λ)

p1 = ones(n)/n
v = float([X[:,i]⋅X[:,i] for i=1:n])
p2 = v + λ*γ*n
p2 = p2/sum(p2)
p3 = 0.1 + rand(n)
p3 = p3/sum(p3)



dfSDCACompare(X, g, P, 30n, γ, λ, (p1,p2,p3), ("dfSDCA-unif", "dfSDCA-imp", "dfSDCA-rand"), true)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9d07031cd0>)
# Optimal value:  #passes 0.0
# Optimal value:  #passes 1.0
# Optimal value:  #passes 2.0
# Optimal value:  #passes 3.0
# Optimal value:  #passes 4.0
# Optimal value:  #passes 5.0
# Optimal value:  #passes 6.0
# Optimal value:  #passes 7.0
# Optimal value:  #passes 8.0
# Optimal value:  #passes 9.0
# Optimal value:  #passes 10.0
# Optimal value:  #passes 11.0
# Optimal value:  #passes 12.0
# Optimal value:  #passes 13.0
# Optimal value:  #passes 14.0
# Optimal value:  #passes 15.0
# Optimal value:  #passes 16.0
# Optimal value:  #passes 17.0
# Optimal value:  #passes 18.0
# Optimal value:  #passes 19.0
# Optimal value:  #passes 20.0
# Optimal value:  #passes 21.0
# Optimal value:  #passes 22.0
# Optimal value:  #passes 23.0
# Optimal value:  #passes 24.0
# Optimal value:  #passes 25.0
# Optimal value:  #passes 26.0
# Optimal value:  #passes 27.0
# Optimal value:  #passes 28.0
# Optimal value:  #passes 29.0
# Optimal value:  #passes 30.0
# Optimal value:  #passes 31.0
# Optimal value:  #passes 32.0
# Optimal value:  #passes 33.0
# Optimal value:  #passes 34.0
# Optimal value:  #passes 35.0
# Optimal value:  #passes 36.0
# Optimal value:  #passes 37.0
# Optimal value:  #passes 38.0
# Optimal value:  #passes 39.0
# Optimal value:  #passes 40.0
# Optimal value:  #passes 41.0
# Optimal value:  #passes 42.0
# Optimal value:  #passes 43.0
# Optimal value:  #passes 44.0
# Optimal value:  #passes 45.0
# Optimal value:  #passes 46.0
# Optimal value:  #passes 47.0
# Optimal value:  #passes 48.0
# Optimal value:  #passes 49.0
# Optimal value:  #passes 50.0
# Optimal value:  #passes 51.0
# Optimal value:  #passes 52.0
# Optimal value:  #passes 53.0
# Optimal value:  #passes 54.0
# Optimal value:  #passes 55.0
# Optimal value:  #passes 56.0
# Optimal value:  #passes 57.0
# Optimal value:  #passes 58.0
# Optimal value:  #passes 59.0
# Optimal value:  #passes 60.0
# Optimal value finished!
# dfSDCA-unif:  #passes 0.0, function value: 2.772588722239787
# dfSDCA-unif:  #passes 1.0, function value: 0.041844543391864004
# dfSDCA-unif:  #passes 2.0, function value: 0.029322526150726162
# dfSDCA-unif:  #passes 3.0, function value: 0.026052445770842474
# dfSDCA-unif:  #passes 4.0, function value: 0.024269541400279336
# dfSDCA-unif:  #passes 5.0, function value: 0.02371268582946006
# dfSDCA-unif:  #passes 6.0, function value: 0.02358272565703948
# dfSDCA-unif:  #passes 7.0, function value: 0.023183776983617926
# dfSDCA-unif:  #passes 8.0, function value: 0.023071842298452994
# dfSDCA-unif:  #passes 9.0, function value: 0.022970823876077184
# dfSDCA-unif:  #passes 10.0, function value: 0.022923697108662197
# dfSDCA-unif:  #passes 11.0, function value: 0.022881227566007113
# dfSDCA-unif:  #passes 12.0, function value: 0.022866851597745888
# dfSDCA-unif:  #passes 13.0, function value: 0.022839992369858376
# dfSDCA-unif:  #passes 14.0, function value: 0.022830397540755068
# dfSDCA-unif:  #passes 15.0, function value: 0.022828538816916103
# dfSDCA-unif:  #passes 16.0, function value: 0.022804551102757427
# dfSDCA-unif:  #passes 17.0, function value: 0.02281267082346084
# dfSDCA-unif:  #passes 18.0, function value: 0.022805006965165124
# dfSDCA-unif:  #passes 19.0, function value: 0.022789873944260464
# dfSDCA-unif:  #passes 20.0, function value: 0.022796833452147728
# dfSDCA-unif:  #passes 21.0, function value: 0.022785246745142824
# dfSDCA-unif:  #passes 22.0, function value: 0.022779068700351807
# dfSDCA-unif:  #passes 23.0, function value: 0.022791556857221677
# dfSDCA-unif:  #passes 24.0, function value: 0.022785574837568538
# dfSDCA-unif:  #passes 25.0, function value: 0.02277511292541083
# dfSDCA-unif:  #passes 26.0, function value: 0.02277317918329136
# dfSDCA-unif:  #passes 27.0, function value: 0.022767655549858386
# dfSDCA-unif:  #passes 28.0, function value: 0.022766485164209906
# dfSDCA-unif:  #passes 29.0, function value: 0.0227710331944435
# dfSDCA-unif:  #passes 30.0, function value: 0.02276819339097738
# dfSDCA-unif finished!
# dfSDCA-imp:  #passes 0.0, function value: 2.772588722239787
# dfSDCA-imp:  #passes 1.0, function value: 0.04530421441318898
# dfSDCA-imp:  #passes 2.0, function value: 0.029523926356780014
# dfSDCA-imp:  #passes 3.0, function value: 0.025489162005639467
# dfSDCA-imp:  #passes 4.0, function value: 0.0242231906960754
# dfSDCA-imp:  #passes 5.0, function value: 0.024023458475510996
# dfSDCA-imp:  #passes 6.0, function value: 0.023287064057366493
# dfSDCA-imp:  #passes 7.0, function value: 0.02311142882054864
# dfSDCA-imp:  #passes 8.0, function value: 0.023024239176258718
# dfSDCA-imp:  #passes 9.0, function value: 0.02297345455431725
# dfSDCA-imp:  #passes 10.0, function value: 0.022908844982070874
# dfSDCA-imp:  #passes 11.0, function value: 0.02289941658293229
# dfSDCA-imp:  #passes 12.0, function value: 0.02286166390461734
# dfSDCA-imp:  #passes 13.0, function value: 0.022841774380305626
# dfSDCA-imp:  #passes 14.0, function value: 0.022852328805309123
# dfSDCA-imp:  #passes 15.0, function value: 0.022814815160158257
# dfSDCA-imp:  #passes 16.0, function value: 0.022817038269470027
# dfSDCA-imp:  #passes 17.0, function value: 0.02281854795957481
# dfSDCA-imp:  #passes 18.0, function value: 0.022797502381124896
# dfSDCA-imp:  #passes 19.0, function value: 0.02278990113102191
# dfSDCA-imp:  #passes 20.0, function value: 0.022791277486939113
# dfSDCA-imp:  #passes 21.0, function value: 0.022788482802020674
# dfSDCA-imp:  #passes 22.0, function value: 0.022793026345662888
# dfSDCA-imp:  #passes 23.0, function value: 0.022782556252979598
# dfSDCA-imp:  #passes 24.0, function value: 0.02277820643569709
# dfSDCA-imp:  #passes 25.0, function value: 0.022774842159764493
# dfSDCA-imp:  #passes 26.0, function value: 0.022791772420102007
# dfSDCA-imp:  #passes 27.0, function value: 0.02277072826352996
# dfSDCA-imp:  #passes 28.0, function value: 0.022769581776718097
# dfSDCA-imp:  #passes 29.0, function value: 0.02276872376153072
# dfSDCA-imp:  #passes 30.0, function value: 0.022765633921290617
# dfSDCA-imp finished!
# dfSDCA-rand:  #passes 0.0, function value: 2.772588722239787
# dfSDCA-rand:  #passes 1.0, function value: 0.14721036376559712
# dfSDCA-rand:  #passes 2.0, function value: 0.09084232500498966
# dfSDCA-rand:  #passes 3.0, function value: 0.0689026235571088
# dfSDCA-rand:  #passes 4.0, function value: 0.05775179077287425
# dfSDCA-rand:  #passes 5.0, function value: 0.04664768696938536
# dfSDCA-rand:  #passes 6.0, function value: 0.040742896732044925
# dfSDCA-rand:  #passes 7.0, function value: 0.03738125108846656
# dfSDCA-rand:  #passes 8.0, function value: 0.034798570327288426
# dfSDCA-rand:  #passes 9.0, function value: 0.0330385086809709
# dfSDCA-rand:  #passes 10.0, function value: 0.031623198127600886
# dfSDCA-rand:  #passes 11.0, function value: 0.030113964476635967
# dfSDCA-rand:  #passes 12.0, function value: 0.029503910950080887
# dfSDCA-rand:  #passes 13.0, function value: 0.02818896140837862
# dfSDCA-rand:  #passes 14.0, function value: 0.027530487986008663
# dfSDCA-rand:  #passes 15.0, function value: 0.026940729256413914
# dfSDCA-rand:  #passes 16.0, function value: 0.02645017428211499
# dfSDCA-rand:  #passes 17.0, function value: 0.025996755597323923
# dfSDCA-rand:  #passes 18.0, function value: 0.025627483533388465
# dfSDCA-rand:  #passes 19.0, function value: 0.025304227130679757
# dfSDCA-rand:  #passes 20.0, function value: 0.025033309091811815
# dfSDCA-rand:  #passes 21.0, function value: 0.02483959580962743
# dfSDCA-rand:  #passes 22.0, function value: 0.02471379309855438
# dfSDCA-rand:  #passes 23.0, function value: 0.024462660335265025
# dfSDCA-rand:  #passes 24.0, function value: 0.024284774265551416
# dfSDCA-rand:  #passes 25.0, function value: 0.024137201650810992
# dfSDCA-rand:  #passes 26.0, function value: 0.02402267865371753
# dfSDCA-rand:  #passes 27.0, function value: 0.023911439702908207
# dfSDCA-rand:  #passes 28.0, function value: 0.023843080894650488
# dfSDCA-rand:  #passes 29.0, function value: 0.023753347730184345
# dfSDCA-rand:  #passes 30.0, function value: 0.023662235175104736
# dfSDCA-rand finished!

# %% [markdown]
# ## 8. Further Exercises
#
# ### Exercise C
#
# Write a new function, <b>dfSDCA10</b>, which always updates a set of $10$ variables $\alpha_i$, chosen uniformly at random. That is, $|S_t|=10$ with probability 1, and all such subsets of cardinality 10 are equaly likely chosen. Make sure the stepsize parameters $v$ are chosen correctly, following theoretical recommendation.

# %%
function samplingK(k, n) 
    reservoir = collect(1:k)
    for i=(k+1):n
        pos = rand(1:i)
        if pos <= k
            reservoir[pos] = i
        end
    end
    return reservoir
end
# Out:
# samplingK (generic function with 1 method)

# %%
function dfSDCA10(X::SparseMatrixCSC, g::Function, P::Function, p::Array{Float64,1}, T::Int64, 
    γ::Float64, λ::Float64, track::Bool, AlgLabel::ASCIIString)

 
    
(d,n) = size(X)
    
       p=ones(n)*10/n # probability vector is given
    
if track
        Pvalue = zeros(ifloor(T/n)+1) # prepares the array of function values
end
    
    ω=zeros(d)
    for i=1:d
        ω[i]=sum([X[i,j]!=0 for j=1:n])
    end
    
    λ_S=1.+(ω.-1).*(9)./(n-1)
            
    v=zeros(n)
    for i=1:n
            v[i]=sum((X[:,i].^2).* λ_S)
    end


θ = minimum(p*λ*γ*n./(v + λ*γ*n)) # step size



α = zeros(n) # the starting points are set to zero vectors for simplicity
w = sum([X[:,i]*α[i] for i=1:n])/γ*n

    #we need to make T/(10*n) iterations in order to do T/n passes through data  
    eps=0.000000001
    counter=1
    t=0
    while counter <= ifloor(T/n)+1
        
        if (t*10/n-floor(t*10/n))*n <10-eps # every n/10 iterations store the function value and prints a message about progress
            if track
                    Pvalue[counter] = P(w)
                    counter+=1
            end
        end
    
    
        for i in samplingK(10,n)      
            Δ = g(w,i) + α[i] # store the update as Δ
            α[i] -= θ/p[i] *(Δ)
            w -= (X[:,i]*θ*Δ) / (λ*n*p[i]) # vector - matrix = matrix
        end
        w = vec(w) # matrix -> vector
        t+=1
    end
    println(t)
println( AlgLabel ," finished!" )

if track # return function values or w, dependig on track
    return Pvalue
else
    return w
end
    
end
# Out:
# dfSDCA10 (generic function with 1 method)

# %%
function dfSDCA10Compare(X::SparseMatrixCSC, g::Function, P::Function, 
    T::Int64, γ::Float64, λ::Float64, plist, AlgLabel, progress::Bool)
    v = float([X[:,i]⋅X[:,i] for i=1:n])
    p_imp = v + λ*γ*n
    p_imp = p_imp/sum(p_imp)
    wstar = dfSDCA(X, g, P, p_imp, 2T, γ, λ, false, "Optimal value", progress)
    Pstar = P(wstar)
    Pvalues = [dfSDCA(X,  g, P, plist[i], T, γ, λ, true, AlgLabel[i], progress) for i = 1:length(plist)]
    push!(Pvalues,dfSDCA10(X,  g, P, ones(n)*10/n, T, γ, λ, true, "dfSDCA10" )) 
    ShowConvergence(Pvalues, AlgLabel, Pstar)
end
# Out:
# dfSDCA10Compare (generic function with 1 method)

# %%
X,y = ReadData("mushrooms", true)
#X,y = ReadLIBSVM("ijcnn1.tr", (49990,22) ,true)


d,n = size(X)
γ = 1.0
λ = 1/n
g, P = Loss_logistic(X,y,γ,λ)

println(size(X))

p1 = ones(n)/n
v = float([X[:,i]⋅X[:,i] for i=1:n])
p2 = v + λ*γ*n
p2 = p2/sum(p2)
dfSDCA10Compare(X, g, P, 20n, γ, λ, (p1,p2), ("dfSDCA-unif", "dfSDCA-imp", "dfSDCA10"), true)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9d068d6250>)
# (112,8124)
# Optimal value:  #passes 0.0
# Optimal value:  #passes 1.0
# Optimal value:  #passes 2.0
# Optimal value:  #passes 3.0
# Optimal value:  #passes 4.0
# Optimal value:  #passes 5.0
# Optimal value:  #passes 6.0
# Optimal value:  #passes 7.0
# Optimal value:  #passes 8.0
# Optimal value:  #passes 9.0
# Optimal value:  #passes 10.0
# Optimal value:  #passes 11.0
# Optimal value:  #passes 12.0
# Optimal value:  #passes 13.0
# Optimal value:  #passes 14.0
# Optimal value:  #passes 15.0
# Optimal value:  #passes 16.0
# Optimal value:  #passes 17.0
# Optimal value:  #passes 18.0
# Optimal value:  #passes 19.0
# Optimal value:  #passes 20.0
# Optimal value:  #passes 21.0
# Optimal value:  #passes 22.0
# Optimal value:  #passes 23.0
# Optimal value:  #passes 24.0
# Optimal value:  #passes 25.0
# Optimal value:  #passes 26.0
# Optimal value:  #passes 27.0
# Optimal value:  #passes 28.0
# Optimal value:  #passes 29.0
# Optimal value:  #passes 30.0
# Optimal value:  #passes 31.0
# Optimal value:  #passes 32.0
# Optimal value:  #passes 33.0
# Optimal value:  #passes 34.0
# Optimal value:  #passes 35.0
# Optimal value:  #passes 36.0
# Optimal value:  #passes 37.0
# Optimal value:  #passes 38.0
# Optimal value:  #passes 39.0
# Optimal value:  #passes 40.0
# Optimal value finished!
# dfSDCA-unif:  #passes 0.0, function value: 2.772588722239787
# dfSDCA-unif:  #passes 1.0, function value: 0.04562327436353453
# dfSDCA-unif:  #passes 2.0, function value: 0.029326816159837423
# dfSDCA-unif:  #passes 3.0, function value: 0.026151976388312237
# dfSDCA-unif:  #passes 4.0, function value: 0.024412058608658603
# dfSDCA-unif:  #passes 5.0, function value: 0.024049526976442172
# dfSDCA-unif:  #passes 6.0, function value: 0.024125982479585993
# dfSDCA-unif:  #passes 7.0, function value: 0.023207468481143148
# dfSDCA-unif:  #passes 8.0, function value: 0.023067725337034377
# dfSDCA-unif:  #passes 9.0, function value: 0.022987087471726585
# dfSDCA-unif:  #passes 10.0, function value: 0.022960461466629226
# dfSDCA-unif:  #passes 11.0, function value: 0.022956467078606834
# dfSDCA-unif:  #passes 12.0, function value: 0.02286584374407129
# dfSDCA-unif:  #passes 13.0, function value: 0.02285708665569482
# dfSDCA-unif:  #passes 14.0, function value: 0.02283191709909083
# dfSDCA-unif:  #passes 15.0, function value: 0.022824008606250543
# dfSDCA-unif:  #passes 16.0, function value: 0.02281516157283467
# dfSDCA-unif:  #passes 17.0, function value: 0.02281257949303183
# dfSDCA-unif:  #passes 18.0, function value: 0.022801628419628735
# dfSDCA-unif:  #passes 19.0, function value: 0.022821799264029993
# dfSDCA-unif:  #passes 20.0, function value: 0.02278759781235027
# dfSDCA-unif finished!
# dfSDCA-imp:  #passes 0.0, function value: 2.772588722239787
# dfSDCA-imp:  #passes 1.0, function value: 0.044403289171708146
# dfSDCA-imp:  #passes 2.0, function value: 0.031135689804968218
# dfSDCA-imp:  #passes 3.0, function value: 0.025995592147138993
# dfSDCA-imp:  #passes 4.0, function value: 0.024500390776702775
# dfSDCA-imp:  #passes 5.0, function value: 0.023895949814387717
# dfSDCA-imp:  #passes 6.0, function value: 0.023476235119391453
# dfSDCA-imp:  #passes 7.0, function value: 0.023238974652451068
# dfSDCA-imp:  #passes 8.0, function value: 0.023117385167884384
# dfSDCA-imp:  #passes 9.0, function value: 0.02304155989538234
# dfSDCA-imp:  #passes 10.0, function value: 0.022936636451769885
# dfSDCA-imp:  #passes 11.0, function value: 0.02288942968620428
# dfSDCA-imp:  #passes 12.0, function value: 0.02286250454451667
# dfSDCA-imp:  #passes 13.0, function value: 0.022838566240867973
# dfSDCA-imp:  #passes 14.0, function value: 0.02285049040002376
# dfSDCA-imp:  #passes 15.0, function value: 0.02282931727624663
# dfSDCA-imp:  #passes 16.0, function value: 0.022845668045148926
# dfSDCA-imp:  #passes 17.0, function value: 0.02280084862377217
# dfSDCA-imp:  #passes 18.0, function value: 0.02280681930612641
# dfSDCA-imp:  #passes 19.0, function value: 0.022794811093894016
# dfSDCA-imp:  #passes 20.0, function value: 0.022784422548138016
# dfSDCA-imp finished!
# 16249
# dfSDCA10 finished!

# %% [markdown]
# ### Exercise D
#
# Write a new function, <b>dfSDCAall</b>, which in each iteration updates all variables $\alpha_i$. This method is deterministic. Compare its behavior with dfSDCA with uniform sampling of a single "dual" variable in a single plot.

# %%
function dfSDCAall(X::SparseMatrixCSC, g::Function, P::Function, p::Array{Float64,1}, T::Int64, 
    γ::Float64, λ::Float64, track::Bool, AlgLabel::ASCIIString)
    
(d,n) = size(X)
    
if track
        Pvalue = zeros(ifloor(T/n)+1) # prepares the array of function values
end
    
    
    λ_max=eigmax(full(X'*X))
    v=ones(n)*λ_max


θ = minimum(p*λ*γ*n./(v + λ*γ*n)) # step size



α = zeros(n) # the starting points are set to zero vectors for simplicity
w = sum([X[:,i]*α[i] for i=1:n])/γ*n

for t=0:floor((T/n))

    if 0 == 0 # every iteration store the function value and prints a message about progress
        if track
            Pvalue[t + 1] = P(w)
        end
    end

    for i in samplingK(n,n)      
        Δ = g(w,i) + α[i] # store the update as Δ
        α[i] -= θ/p[i] *(Δ)
        w -= (X[:,i]*θ*Δ) / (λ*n*p[i]) # vector - matrix = matrix
    end
    w = vec(w) # matrix -> vector 
end

println( AlgLabel ," finished!" )

if track # return function values or w, dependig on track
    return Pvalue
else
    return w
end
    
end
# Out:
# dfSDCAall (generic function with 1 method)

# %%
function dfSDCAallCompare(X::SparseMatrixCSC, g::Function, P::Function, 
    T::Int64, γ::Float64, λ::Float64, plist, AlgLabel, progress::Bool)
    v = float([X[:,i]⋅X[:,i] for i=1:n])
    p_imp = v + λ*γ*n
    p_imp = p_imp/sum(p_imp)
    wstar = dfSDCA(X, g, P, p_imp, 2T, γ, λ, false, "Optimal value", progress)
    Pstar = P(wstar)
    Pvalues = [dfSDCA(X, g, P, plist[i], T, γ, λ, true, AlgLabel[i], progress) for i = 1:length(plist)]
    push!(Pvalues,dfSDCAall(X, g, P, ones(n), T, γ, λ, true, "dfSDCAall" )) 
    ShowConvergence(Pvalues, AlgLabel, Pstar)
end
# Out:
# dfSDCAallCompare (generic function with 1 method)

# %%
n = 1000
d = 100
X = sprand(d, n, 0.1)
y = rand(n)

d,n = size(X)
γ = 1.0
λ = 1/n
g, P = Loss_logistic(X,y,γ,λ)

println(size(X))

p1 = ones(n)/n
v = float([X[:,i]⋅X[:,i] for i=1:n])
p2 = v + λ*γ*n
p2 = p2/sum(p2)

dfSDCAallCompare(X, g, P, 30n, γ, λ, (p1,p2), ("dfSDCA-unif","dfSDCA-imp",  "dfSDCAall"), true)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f2b27215490>)
# (100,1000)
# Optimal value:  #passes 0.0
# Optimal value:  #passes 1.0
# Optimal value:  #passes 2.0
# Optimal value:  #passes 3.0
# Optimal value:  #passes 4.0
# Optimal value:  #passes 5.0
# Optimal value:  #passes 6.0
# Optimal value:  #passes 7.0
# Optimal value:  #passes 8.0
# Optimal value:  #passes 9.0
# Optimal value:  #passes 10.0
# Optimal value:  #passes 11.0
# Optimal value:  #passes 12.0
# Optimal value:  #passes 13.0
# Optimal value:  #passes 14.0
# Optimal value:  #passes 15.0
# Optimal value:  #passes 16.0
# Optimal value:  #passes 17.0
# Optimal value:  #passes 18.0
# Optimal value:  #passes 19.0
# Optimal value:  #passes 20.0
# Optimal value:  #passes 21.0
# Optimal value:  #passes 22.0
# Optimal value:  #passes 23.0
# Optimal value:  #passes 24.0
# Optimal value:  #passes 25.0
# Optimal value:  #passes 26.0
# Optimal value:  #passes 27.0
# Optimal value:  #passes 28.0
# Optimal value:  #passes 29.0
# Optimal value:  #passes 30.0
# Optimal value:  #passes 31.0
# Optimal value:  #passes 32.0
# Optimal value:  #passes 33.0
# Optimal value:  #passes 34.0
# Optimal value:  #passes 35.0
# Optimal value:  #passes 36.0
# Optimal value:  #passes 37.0
# Optimal value:  #passes 38.0
# Optimal value:  #passes 39.0
# Optimal value:  #passes 40.0
# Optimal value:  #passes 41.0
# Optimal value:  #passes 42.0
# Optimal value:  #passes 43.0
# Optimal value:  #passes 44.0
# Optimal value:  #passes 45.0
# Optimal value:  #passes 46.0
# Optimal value:  #passes 47.0
# Optimal value:  #passes 48.0
# Optimal value:  #passes 49.0
# Optimal value:  #passes 50.0
# Optimal value:  #passes 51.0
# Optimal value:  #passes 52.0
# Optimal value:  #passes 53.0
# Optimal value:  #passes 54.0
# Optimal value:  #passes 55.0
# Optimal value:  #passes 56.0
# Optimal value:  #passes 57.0
# Optimal value:  #passes 58.0
# Optimal value:  #passes 59.0
# Optimal value:  #passes 60.0
# Optimal value finished!
# dfSDCA-unif:  #passes 0.0, function value: 2.7725887222397865
# dfSDCA-unif:  #passes 1.0, function value: 0.6855984917781713
# dfSDCA-unif:  #passes 2.0, function value: 0.6073808977101167
# dfSDCA-unif:  #passes 3.0, function value: 0.583282362830273
# dfSDCA-unif:  #passes 4.0, function value: 0.5733157536089679
# dfSDCA-unif:  #passes 5.0, function value: 0.5690612978140948
# dfSDCA-unif:  #passes 6.0, function value: 0.5672046896829726
# dfSDCA-unif:  #passes 7.0, function value: 0.5663151997559045
# dfSDCA-unif:  #passes 8.0, function value: 0.5656573524561732
# dfSDCA-unif:  #passes 9.0, function value: 0.5654622892848356
# dfSDCA-unif:  #passes 10.0, function value: 0.5652278500775039
# dfSDCA-unif:  #passes 11.0, function value: 0.5650825620036094
# dfSDCA-unif:  #passes 12.0, function value: 0.5649912635226914
# dfSDCA-unif:  #passes 13.0, function value: 0.56491495903336
# dfSDCA-unif:  #passes 14.0, function value: 0.5648832909551195
# dfSDCA-unif:  #passes 15.0, function value: 0.5648504971376278
# dfSDCA-unif:  #passes 16.0, function value: 0.5648318572950617
# dfSDCA-unif:  #passes 17.0, function value: 0.5648212015776062
# dfSDCA-unif:  #passes 18.0, function value: 0.5648058802506476
# dfSDCA-unif:  #passes 19.0, function value: 0.5647974815503229
# dfSDCA-unif:  #passes 20.0, function value: 0.5647904262059358
# dfSDCA-unif:  #passes 21.0, function value: 0.5647856437252844
# dfSDCA-unif:  #passes 22.0, function value: 0.5647802820136849
# dfSDCA-unif:  #passes 23.0, function value: 0.5647788517172004
# dfSDCA-unif:  #passes 24.0, function value: 0.5647764613227509
# dfSDCA-unif:  #passes 25.0, function value: 0.564774700696895
# dfSDCA-unif:  #passes 26.0, function value: 0.5647734318572227
# dfSDCA-unif:  #passes 27.0, function value: 0.5647718902869355
# dfSDCA-unif:  #passes 28.0, function value: 0.5647709293807577
# dfSDCA-unif:  #passes 29.0, function value: 0.5647701741424365
# dfSDCA-unif:  #passes 30.0, function value: 0.564769154875956
# dfSDCA-unif finished!
# dfSDCA-imp:  #passes 0.0, function value: 2.7725887222397865
# dfSDCA-imp:  #passes 1.0, function value: 0.6087293399222441
# dfSDCA-imp:  #passes 2.0, function value: 0.576345290056393
# dfSDCA-imp:  #passes 3.0, function value: 0.5680751135273884
# dfSDCA-imp:  #passes 4.0, function value: 0.5662582610628737
# dfSDCA-imp:  #passes 5.0, function value: 0.5658532252917938
# dfSDCA-imp:  #passes 6.0, function value: 0.565432427767324
# dfSDCA-imp:  #passes 7.0, function value: 0.565176783502179
# dfSDCA-imp:  #passes 8.0, function value: 0.5650411147700276
# dfSDCA-imp:  #passes 9.0, function value: 0.5649635964138411
# dfSDCA-imp:  #passes 10.0, function value: 0.5648279239047861
# dfSDCA-imp:  #passes 11.0, function value: 0.5648021326207286
# dfSDCA-imp:  #passes 12.0, function value: 0.5647882185886599
# dfSDCA-imp:  #passes 13.0, function value: 0.564778920482163
# dfSDCA-imp:  #passes 14.0, function value: 0.5647761598621592
# dfSDCA-imp:  #passes 15.0, function value: 0.5647747959986608
# dfSDCA-imp:  #passes 16.0, function value: 0.5647716364105289
# dfSDCA-imp:  #passes 17.0, function value: 0.5647702101935067
# dfSDCA-imp:  #passes 18.0, function value: 0.5647704484397227
# dfSDCA-imp:  #passes 19.0, function value: 0.5647698759779897
# dfSDCA-imp:  #passes 20.0, function value: 0.5647689268110978
# dfSDCA-imp:  #passes 21.0, function value: 0.5647687426944494
# dfSDCA-imp:  #passes 22.0, function value: 0.5647685053990725
# dfSDCA-imp:  #passes 23.0, function value: 0.5647664786131324
# dfSDCA-imp:  #passes 24.0, function value: 0.564766504191137
# dfSDCA-imp:  #passes 25.0, function value: 0.5647663921113116
# dfSDCA-imp:  #passes 26.0, function value: 0.5647663682775633
# dfSDCA-imp:  #passes 27.0, function value: 0.5647663266863797
# dfSDCA-imp:  #passes 28.0, function value: 0.564766312512197
# dfSDCA-imp:  #passes 29.0, function value: 0.564766305832248
# dfSDCA-imp:  #passes 30.0, function value: 0.5647662876604949
# dfSDCA-imp finished!
# dfSDCAall finished!

# %% [markdown]
# ### Exercise E
#
# Code up the stochastic gradient descent algorithm (with a fixed stepsize). For a range of stepsizes, plot its behavior (as it is done for dfSDCA in the above plots). Compare with dfSDCA.

# %%
function SGD( X::SparseMatrixCSC, g::Function, P::Function, T::Int64, 
    γ::Float64, λ::Float64, θ:: Float64, track::Bool, AlgLabel::ASCIIString, progress::Bool)
    
#θ- vector of stepsizes
    
(d,n) = size(X)
    
if track
        Pvalue = zeros(ifloor(T/n)+1) # prepares the array of function values
end
     

 

  w=zeros(d)
  gcan=zeros(d)
for t=0:T

    if t % n == 0 # every n iterations store the function value and prints a message about progress

        if track
            Pvalue[t/n + 1] = P(w)
            if progress
                println(AlgLabel, ":  #passes $(t/n), function value: $(Pvalue[t/n + 1])")
            end
        else
            if progress
                println(AlgLabel, ":  #passes $(t/n)")
            end
        end
    end


        i=int(1+floor(rand()*n))
        w-= θ*(X[:,i]*g(w,i)+λ*w)
        w = vec(w) # matrix -> vector 

end

println( AlgLabel ," finished!" )

if track # return function values or w, dependig on track
    return Pvalue
else
    return w
end
    
end
# Out:
# SGD (generic function with 1 method)

# %%
function SGDCompare(X::SparseMatrixCSC,  g::Function, P::Function, 
    T::Int64, γ::Float64, λ::Float64, θ_list::Array{Float64,1}, progress::Bool)
    v = float([X[:,i]⋅X[:,i] for i=1:n])
    p_imp = v + λ*γ*n
    p_imp = p_imp/sum(p_imp)
    wstar = dfSDCA(X, g, P, p_imp, 2T, γ, λ, false, "Optimal value", progress)
    Pstar = P(wstar)
    Pvalues = [SGD(X, g, P, T, γ, λ,θ, true, "SGD - $(θ)", progress) for θ in θ_list]
    push!(Pvalues, dfSDCA(X, g, P, p_imp, T, γ, λ, true, "dfSDCA_imp", progress))
    AlgLabel=["SGD - $(θ)" for θ in θ_list]
    push!(AlgLabel,"dfSDCA_imp")
    ShowConvergence(Pvalues, AlgLabel, Pstar)
end
# Out:
# SGDCompare (generic function with 1 method)

# %%
n = 1000
d = 100
X = sprand(d, n, 0.1)
y = rand(n)


d,n = size(X)
γ = 1.0
λ = 1/n
g, P = Loss_logistic(X,y,γ,λ)

θ_list=linspace(0.01,1, 3)


SGDCompare(X,  g, P, 70n, γ, λ,θ_list, true)
# Out:
# Optimal value:  #passes 0.0
# Optimal value:  #passes 1.0
# Optimal value:  #passes 2.0
# Optimal value:  #passes 3.0
# Optimal value:  #passes 4.0
# Optimal value:  #passes 5.0
# Optimal value:  #passes 6.0
# Optimal value:  #passes 7.0
# Optimal value:  #passes 8.0
# Optimal value:  #passes 9.0
# Optimal value:  #passes 10.0
# Optimal value:  #passes 11.0
# Optimal value:  #passes 12.0
# Optimal value:  #passes 13.0
# Optimal value:  #passes 14.0
# Optimal value:  #passes 15.0
# Optimal value:  #passes 16.0
# Optimal value:  #passes 17.0
# Optimal value:  #passes 18.0
# Optimal value:  #passes 19.0
# Optimal value:  #passes 20.0
# Optimal value:  #passes 21.0
# Optimal value:  #passes 22.0
# Optimal value:  #passes 23.0
# Optimal value:  #passes 24.0
# Optimal value:  #passes 25.0
# Optimal value:  #passes 26.0
# Optimal value:  #passes 27.0
# Optimal value:  #passes 28.0
# Optimal value:  #passes 29.0
# Optimal value:  #passes 30.0
# Optimal value:  #passes 31.0
# Optimal value:  #passes 32.0
# Optimal value:  #passes 33.0
# Optimal value:  #passes 34.0
# Optimal value:  #passes 35.0
# Optimal value:  #passes 36.0
# Optimal value:  #passes 37.0
# Optimal value:  #passes 38.0
# Optimal value:  #passes 39.0
# Optimal value:  #passes 40.0
# Optimal value:  #passes 41.0
# Optimal value:  #passes 42.0
# Optimal value:  #passes 43.0
# Optimal value:  #passes 44.0
# Optimal value:  #passes 45.0
# Optimal value:  #passes 46.0
# Optimal value:  #passes 47.0
# Optimal value:  #passes 48.0
# Optimal value:  #passes 49.0
# Optimal value:  #passes 50.0
# Optimal value:  #passes 51.0
# Optimal value:  #passes 52.0
# Optimal value:  #passes 53.0
# Optimal value:  #passes 54.0
# Optimal value:  #passes 55.0
# Optimal value:  #passes 56.0
# Optimal value:  #passes 57.0
# Optimal value:  #passes 58.0
# Optimal value:  #passes 59.0
# Optimal value:  #passes 60.0
# Optimal value:  #passes 61.0
# Optimal value:  #passes 62.0
# Optimal value:  #passes 63.0
# Optimal value:  #passes 64.0
# Optimal value:  #passes 65.0
# Optimal value:  #passes 66.0
# Optimal value:  #passes 67.0
# Optimal value:  #passes 68.0
# Optimal value:  #passes 69.0
# Optimal value:  #passes 70.0
# Optimal value:  #passes 71.0
# Optimal value:  #passes 72.0
# Optimal value:  #passes 73.0
# Optimal value:  #passes 74.0
# Optimal value:  #passes 75.0
# Optimal value:  #passes 76.0
# Optimal value:  #passes 77.0
# Optimal value:  #passes 78.0
# Optimal value:  #passes 79.0
# Optimal value:  #passes 80.0
# Optimal value:  #passes 81.0
# Optimal value:  #passes 82.0
# Optimal value:  #passes 83.0
# Optimal value:  #passes 84.0
# Optimal value:  #passes 85.0
# Optimal value:  #passes 86.0
# Optimal value:  #passes 87.0
# Optimal value:  #passes 88.0
# Optimal value:  #passes 89.0
# Optimal value:  #passes 90.0
# Optimal value:  #passes 91.0
# Optimal value:  #passes 92.0
# Optimal value:  #passes 93.0
# Optimal value:  #passes 94.0
# Optimal value:  #passes 95.0
# Optimal value:  #passes 96.0
# Optimal value:  #passes 97.0
# Optimal value:  #passes 98.0
# Optimal value:  #passes 99.0
# Optimal value:  #passes 100.0
# Optimal value:  #passes 101.0
# Optimal value:  #passes 102.0
# Optimal value:  #passes 103.0
# Optimal value:  #passes 104.0
# Optimal value:  #passes 105.0
# Optimal value:  #passes 106.0
# Optimal value:  #passes 107.0
# Optimal value:  #passes 108.0
# Optimal value:  #passes 109.0
# Optimal value:  #passes 110.0
# Optimal value:  #passes 111.0
# Optimal value:  #passes 112.0
# Optimal value:  #passes 113.0
# Optimal value:  #passes 114.0
# Optimal value:  #passes 115.0
# Optimal value:  #passes 116.0
# Optimal value:  #passes 117.0
# Optimal value:  #passes 118.0
# Optimal value:  #passes 119.0
# Optimal value:  #passes 120.0
# Optimal value:  #passes 121.0
# Optimal value:  #passes 122.0
# Optimal value:  #passes 123.0
# Optimal value:  #passes 124.0
# Optimal value:  #passes 125.0
# Optimal value:  #passes 126.0
# Optimal value:  #passes 127.0
# Optimal value:  #passes 128.0
# Optimal value:  #passes 129.0
# Optimal value:  #passes 130.0
# Optimal value:  #passes 131.0
# Optimal value:  #passes 132.0
# Optimal value:  #passes 133.0
# Optimal value:  #passes 134.0
# Optimal value:  #passes 135.0
# Optimal value:  #passes 136.0
# Optimal value:  #passes 137.0
# Optimal value:  #passes 138.0
# Optimal value:  #passes 139.0
# Optimal value:  #passes 140.0
# Optimal value finished!
# SGD - 0.01:  #passes 0.0, function value: 2.7725887222397865
# SGD - 0.01:  #passes 1.0, function value: 1.5841499085998965
# SGD - 0.01:  #passes 2.0, function value: 1.2390622137989191
# SGD - 0.01:  #passes 3.0, function value: 1.0695573258633018
# SGD - 0.01:  #passes 4.0, function value: 0.9688397585811772
# SGD - 0.01:  #passes 5.0, function value: 0.8977619638053348
# SGD - 0.01:  #passes 6.0, function value: 0.8481272910738327
# SGD - 0.01:  #passes 7.0, function value: 0.8100410704478405
# SGD - 0.01:  #passes 8.0, function value: 0.7794521198824397
# SGD - 0.01:  #passes 9.0, function value: 0.7551641050328545
# SGD - 0.01:  #passes 10.0, function value: 0.7349007549173328
# SGD - 0.01:  #passes 11.0, function value: 0.717747491633568
# SGD - 0.01:  #passes 12.0, function value: 0.7032750492708679
# SGD - 0.01:  #passes 13.0, function value: 0.6905171416793583
# SGD - 0.01:  #passes 14.0, function value: 0.6801325938372149
# SGD - 0.01:  #passes 15.0, function value: 0.6711486607437577
# SGD - 0.01:  #passes 16.0, function value: 0.663005821902266
# SGD - 0.01:  #passes 17.0, function value: 0.6563974704371844
# SGD - 0.01:  #passes 18.0, function value: 0.6505311716257313
# SGD - 0.01:  #passes 19.0, function value: 0.6449689447310469
# SGD - 0.01:  #passes 20.0, function value: 0.6399290360476453
# SGD - 0.01:  #passes 21.0, function value: 0.6355719422074738
# SGD - 0.01:  #passes 22.0, function value: 0.6313662263946908
# SGD - 0.01:  #passes 23.0, function value: 0.6278127523041729
# SGD - 0.01:  #passes 24.0, function value: 0.6243002693266326
# SGD - 0.01:  #passes 25.0, function value: 0.6214506234195176
# SGD - 0.01:  #passes 26.0, function value: 0.6188863239417036
# SGD - 0.01:  #passes 27.0, function value: 0.6162687361952942
# SGD - 0.01:  #passes 28.0, function value: 0.6139201797802951
# SGD - 0.01:  #passes 29.0, function value: 0.6119141307506125
# SGD - 0.01:  #passes 30.0, function value: 0.6101000288357359
# SGD - 0.01:  #passes 31.0, function value: 0.6083962245775204
# SGD - 0.01:  #passes 32.0, function value: 0.6068171618659173
# SGD - 0.01:  #passes 33.0, function value: 0.60542813619005
# SGD - 0.01:  #passes 34.0, function value: 0.603964404998286
# SGD - 0.01:  #passes 35.0, function value: 0.6027347045545909
# SGD - 0.01:  #passes 36.0, function value: 0.601505189842293
# SGD - 0.01:  #passes 37.0, function value: 0.6004298413875131
# SGD - 0.01:  #passes 38.0, function value: 0.5994000701796549
# SGD - 0.01:  #passes 39.0, function value: 0.5984706598837285
# SGD - 0.01:  #passes 40.0, function value: 0.597598728393268
# SGD - 0.01:  #passes 41.0, function value: 0.5967558504211237
# SGD - 0.01:  #passes 42.0, function value: 0.5960529730147337
# SGD - 0.01:  #passes 43.0, function value: 0.5953104688349578
# SGD - 0.01:  #passes 44.0, function value: 0.5946961256303425
# SGD - 0.01:  #passes 45.0, function value: 0.5939848426210215
# SGD - 0.01:  #passes 46.0, function value: 0.5933964743981122
# SGD - 0.01:  #passes 47.0, function value: 0.5928918249129456
# SGD - 0.01:  #passes 48.0, function value: 0.5924283033840022
# SGD - 0.01:  #passes 49.0, function value: 0.5920053875637041
# SGD - 0.01:  #passes 50.0, function value: 0.5916415718038653
# SGD - 0.01:  #passes 51.0, function value: 0.5912224348833344
# SGD - 0.01:  #passes 52.0, function value: 0.5909576761714512
# SGD - 0.01:  #passes 53.0, function value: 0.5906118647267207
# SGD - 0.01:  #passes 54.0, function value: 0.5902542673124378
# SGD - 0.01:  #passes 55.0, function value: 0.589941396643161
# SGD - 0.01:  #passes 56.0, function value: 0.5896791240902438
# SGD - 0.01:  #passes 57.0, function value: 0.5894112087744375
# SGD - 0.01:  #passes 58.0, function value: 0.5891584470408978
# SGD - 0.01:  #passes 59.0, function value: 0.5888651201987913
# SGD - 0.01:  #passes 60.0, function value: 0.5886449449524876
# SGD - 0.01:  #passes 61.0, function value: 0.58844916609212
# SGD - 0.01:  #passes 62.0, function value: 0.5882027367446453
# SGD - 0.01:  #passes 63.0, function value: 0.5879615927315472
# SGD - 0.01:  #passes 64.0, function value: 0.5877871562520474
# SGD - 0.01:  #passes 65.0, function value: 0.5876471600183689
# SGD - 0.01:  #passes 66.0, function value: 0.587498090888871
# SGD - 0.01:  #passes 67.0, function value: 0.5873654042014173
# SGD - 0.01:  #passes 68.0, function value: 0.5872228524835572
# SGD - 0.01:  #passes 69.0, function value: 0.5870514583147391
# SGD - 0.01:  #passes 70.0, function value: 0.5869213180600533
# SGD - 0.01 finished!
# SGD - 0.505:  #passes 0.0, function value: 2.7725887222397865
# SGD - 0.505:  #passes 1.0, function value: 0.5956354516641333
# SGD - 0.505:  #passes 2.0, function value: 0.5881473635948079
# SGD - 0.505:  #passes 3.0, function value: 0.5869462296059156
# SGD - 0.505:  #passes 4.0, function value: 0.5866649192436625
# SGD - 0.505:  #passes 5.0, function value: 0.5868355776785215
# SGD - 0.505:  #passes 6.0, function value: 0.586843105491081
# SGD - 0.505:  #passes 7.0, function value: 0.5866346161237114
# SGD - 0.505:  #passes 8.0, function value: 0.5865796652888244
# SGD - 0.505:  #passes 9.0, function value: 0.5862508311887324
# SGD - 0.505:  #passes 10.0, function value: 0.5866620854744102
# SGD - 0.505:  #passes 11.0, function value: 0.5864176456688639
# SGD - 0.505:  #passes 12.0, function value: 0.5865941912051489
# SGD - 0.505:  #passes 13.0, function value: 0.5869328505322571
# SGD - 0.505:  #passes 14.0, function value: 0.5865528492917114
# SGD - 0.505:  #passes 15.0, function value: 0.5864938412084884
# SGD - 0.505:  #passes 16.0, function value: 0.5861980578949886
# SGD - 0.505:  #passes 17.0, function value: 0.5866199929022835
# SGD - 0.505:  #passes 18.0, function value: 0.5865687280589061
# SGD - 0.505:  #passes 19.0, function value: 0.5865476607571428
# SGD - 0.505:  #passes 20.0, function value: 0.5862733340896309
# SGD - 0.505:  #passes 21.0, function value: 0.5864324420629943
# SGD - 0.505:  #passes 22.0, function value: 0.5860359361771766
# SGD - 0.505:  #passes 23.0, function value: 0.5863958150230776
# SGD - 0.505:  #passes 24.0, function value: 0.5862437574559543
# SGD - 0.505:  #passes 25.0, function value: 0.5862989903061044
# SGD - 0.505:  #passes 26.0, function value: 0.5864929369896729
# SGD - 0.505:  #passes 27.0, function value: 0.5868526957509511
# SGD - 0.505:  #passes 28.0, function value: 0.5865966502830304
# SGD - 0.505:  #passes 29.0, function value: 0.5869988565703954
# SGD - 0.505:  #passes 30.0, function value: 0.5863665839974105
# SGD - 0.505:  #passes 31.0, function value: 0.5862190957402936
# SGD - 0.505:  #passes 32.0, function value: 0.5864326665096646
# SGD - 0.505:  #passes 33.0, function value: 0.5861959479458856
# SGD - 0.505:  #passes 34.0, function value: 0.5862015505386158
# SGD - 0.505:  #passes 35.0, function value: 0.5867540475212748
# SGD - 0.505:  #passes 36.0, function value: 0.5864931208776103
# SGD - 0.505:  #passes 37.0, function value: 0.586324993037183
# SGD - 0.505:  #passes 38.0, function value: 0.5861985931461424
# SGD - 0.505:  #passes 39.0, function value: 0.5865469870190468
# SGD - 0.505:  #passes 40.0, function value: 0.5869916532316413
# SGD - 0.505:  #passes 41.0, function value: 0.5865300569072998
# SGD - 0.505:  #passes 42.0, function value: 0.5869369953516927
# SGD - 0.505:  #passes 43.0, function value: 0.5864993882356422
# SGD - 0.505:  #passes 44.0, function value: 0.5864296304145972
# SGD - 0.505:  #passes 45.0, function value: 0.5862356937099815
# SGD - 0.505:  #passes 46.0, function value: 0.5866761198215795
# SGD - 0.505:  #passes 47.0, function value: 0.5862198756309541
# SGD - 0.505:  #passes 48.0, function value: 0.5863255960112401
# SGD - 0.505:  #passes 49.0, function value: 0.5863070639846439
# SGD - 0.505:  #passes 50.0, function value: 0.5861602102475414
# SGD - 0.505:  #passes 51.0, function value: 0.5864577502858336
# SGD - 0.505:  #passes 52.0, function value: 0.5872445509364874
# SGD - 0.505:  #passes 53.0, function value: 0.5864308616901891
# SGD - 0.505:  #passes 54.0, function value: 0.5862008642372083
# SGD - 0.505:  #passes 55.0, function value: 0.5863874296174928
# SGD - 0.505:  #passes 56.0, function value: 0.5860802701819203
# SGD - 0.505:  #passes 57.0, function value: 0.5861812127698491
# SGD - 0.505:  #passes 58.0, function value: 0.5867603804241406
# SGD - 0.505:  #passes 59.0, function value: 0.5864763248443756
# SGD - 0.505:  #passes 60.0, function value: 0.5863087747286629
# SGD - 0.505:  #passes 61.0, function value: 0.5865309081914438
# SGD - 0.505:  #passes 62.0, function value: 0.5862789167632683
# SGD - 0.505:  #passes 63.0, function value: 0.5862709165216125
# SGD - 0.505:  #passes 64.0, function value: 0.5865925219596168
# SGD - 0.505:  #passes 65.0, function value: 0.586761699151117
# SGD - 0.505:  #passes 66.0, function value: 0.5865695930020747
# SGD - 0.505:  #passes 67.0, function value: 0.5868058860850999
# SGD - 0.505:  #passes 68.0, function value: 0.586717445789625
# SGD - 0.505:  #passes 69.0, function value: 0.5867103314213014
# SGD - 0.505:  #passes 70.0, function value: 0.586392845579432
# SGD - 0.505 finished!
# SGD - 1.0:  #passes 0.0, function value: 2.7725887222397865
# SGD - 1.0:  #passes 1.0, function value: 0.5884524471335908
# SGD - 1.0:  #passes 2.0, function value: 0.5877266706798355
# SGD - 1.0:  #passes 3.0, function value: 0.5877216121329019
# SGD - 1.0:  #passes 4.0, function value: 0.5877114225162443
# SGD - 1.0:  #passes 5.0, function value: 0.5882409908297261
# SGD - 1.0:  #passes 6.0, function value: 0.5887790354955345
# SGD - 1.0:  #passes 7.0, function value: 0.5883669479641489
# SGD - 1.0:  #passes 8.0, function value: 0.5878120676238154
# SGD - 1.0:  #passes 9.0, function value: 0.5880610072379504
# SGD - 1.0:  #passes 10.0, function value: 0.5892939080885112
# SGD - 1.0:  #passes 11.0, function value: 0.5874013364423254
# SGD - 1.0:  #passes 12.0, function value: 0.588056187471173
# SGD - 1.0:  #passes 13.0, function value: 0.5874535533408702
# SGD - 1.0:  #passes 14.0, function value: 0.5884754289645941
# SGD - 1.0:  #passes 15.0, function value: 0.5882274302801414
# SGD - 1.0:  #passes 16.0, function value: 0.58761978004516
# SGD - 1.0:  #passes 17.0, function value: 0.5876592802104211
# SGD - 1.0:  #passes 18.0, function value: 0.588348030334561
# SGD - 1.0:  #passes 19.0, function value: 0.5884326985975646
# SGD - 1.0:  #passes 20.0, function value: 0.5878884334967032
# SGD - 1.0:  #passes 21.0, function value: 0.5879417153584
# SGD - 1.0:  #passes 22.0, function value: 0.5883473902388912
# SGD - 1.0:  #passes 23.0, function value: 0.5871209850673663
# SGD - 1.0:  #passes 24.0, function value: 0.587327056314194
# SGD - 1.0:  #passes 25.0, function value: 0.5870737423396086
# SGD - 1.0:  #passes 26.0, function value: 0.5887012409296543
# SGD - 1.0:  #passes 27.0, function value: 0.5887942146599925
# SGD - 1.0:  #passes 28.0, function value: 0.5873342100780153
# SGD - 1.0:  #passes 29.0, function value: 0.5881478233816564
# SGD - 1.0:  #passes 30.0, function value: 0.5875494498256588
# SGD - 1.0:  #passes 31.0, function value: 0.5875742914028991
# SGD - 1.0:  #passes 32.0, function value: 0.5880747910054047
# SGD - 1.0:  #passes 33.0, function value: 0.5877458389500021
# SGD - 1.0:  #passes 34.0, function value: 0.5882970771828628
# SGD - 1.0:  #passes 35.0, function value: 0.5883290519635413
# SGD - 1.0:  #passes 36.0, function value: 0.5878711682784805
# SGD - 1.0:  #passes 37.0, function value: 0.5883137524205304
# SGD - 1.0:  #passes 38.0, function value: 0.5881830951546709
# SGD - 1.0:  #passes 39.0, function value: 0.5877918383906209
# SGD - 1.0:  #passes 40.0, function value: 0.5880280304582608
# SGD - 1.0:  #passes 41.0, function value: 0.5887029861614219
# SGD - 1.0:  #passes 42.0, function value: 0.5874790600564259
# SGD - 1.0:  #passes 43.0, function value: 0.5884305016757824
# SGD - 1.0:  #passes 44.0, function value: 0.5888144481093439
# SGD - 1.0:  #passes 45.0, function value: 0.5873778177599109
# SGD - 1.0:  #passes 46.0, function value: 0.5881661593499514
# SGD - 1.0:  #passes 47.0, function value: 0.5883384778734524
# SGD - 1.0:  #passes 48.0, function value: 0.5877986902649623
# SGD - 1.0:  #passes 49.0, function value: 0.5875982353057057
# SGD - 1.0:  #passes 50.0, function value: 0.5886562180588987
# SGD - 1.0:  #passes 51.0, function value: 0.5875046602921263
# SGD - 1.0:  #passes 52.0, function value: 0.5879426414846805
# SGD - 1.0:  #passes 53.0, function value: 0.588263973227054
# SGD - 1.0:  #passes 54.0, function value: 0.5881904657548345
# SGD - 1.0:  #passes 55.0, function value: 0.5877505878815302
# SGD - 1.0:  #passes 56.0, function value: 0.5874132269583003
# SGD - 1.0:  #passes 57.0, function value: 0.588201945002804
# SGD - 1.0:  #passes 58.0, function value: 0.5880685483342518
# SGD - 1.0:  #passes 59.0, function value: 0.5885372665802417
# SGD - 1.0:  #passes 60.0, function value: 0.5877376992762912
# SGD - 1.0:  #passes 61.0, function value: 0.5874335095319273
# SGD - 1.0:  #passes 62.0, function value: 0.587755854170441
# SGD - 1.0:  #passes 63.0, function value: 0.588495533474117
# SGD - 1.0:  #passes 64.0, function value: 0.5884593588703608
# SGD - 1.0:  #passes 65.0, function value: 0.5880308965676748
# SGD - 1.0:  #passes 66.0, function value: 0.5881224774180585
# SGD - 1.0:  #passes 67.0, function value: 0.5880045110727752
# SGD - 1.0:  #passes 68.0, function value: 0.5873783746579503
# SGD - 1.0:  #passes 69.0, function value: 0.5880226028713719
# SGD - 1.0:  #passes 70.0, function value: 0.5877015411659287
# SGD - 1.0 finished!
# dfSDCA_imp:  #passes 0.0, function value: 2.7725887222397865
# dfSDCA_imp:  #passes 1.0, function value: 0.6334303643726448
# dfSDCA_imp:  #passes 2.0, function value: 0.5945372171749179
# dfSDCA_imp:  #passes 3.0, function value: 0.5880459483427838
# dfSDCA_imp:  #passes 4.0, function value: 0.5863740740208405
# dfSDCA_imp:  #passes 5.0, function value: 0.5855239379336068
# dfSDCA_imp:  #passes 6.0, function value: 0.5852629738070777
# dfSDCA_imp:  #passes 7.0, function value: 0.5851055448715119
# dfSDCA_imp:  #passes 8.0, function value: 0.5850304312254365
# dfSDCA_imp:  #passes 9.0, function value: 0.584985410713817
# dfSDCA_imp:  #passes 10.0, function value: 0.5849581463461807
# dfSDCA_imp:  #passes 11.0, function value: 0.5849459634275928
# dfSDCA_imp:  #passes 12.0, function value: 0.5849291395607727
# dfSDCA_imp:  #passes 13.0, function value: 0.5849199796926541
# dfSDCA_imp:  #passes 14.0, function value: 0.5849126183296867
# dfSDCA_imp:  #passes 15.0, function value: 0.5849031418282359
# dfSDCA_imp:  #passes 16.0, function value: 0.5849008508999376
# dfSDCA_imp:  #passes 17.0, function value: 0.5848989666356842
# dfSDCA_imp:  #passes 18.0, function value: 0.5848945016559839
# dfSDCA_imp:  #passes 19.0, function value: 0.5848934622143316
# dfSDCA_imp:  #passes 20.0, function value: 0.5848928938518683
# dfSDCA_imp:  #passes 21.0, function value: 0.5848909946508682
# dfSDCA_imp:  #passes 22.0, function value: 0.584890792944529
# dfSDCA_imp:  #passes 23.0, function value: 0.5848906005768092
# dfSDCA_imp:  #passes 24.0, function value: 0.5848904249766005
# dfSDCA_imp:  #passes 25.0, function value: 0.5848903809172079
# dfSDCA_imp:  #passes 26.0, function value: 0.584890361833049
# dfSDCA_imp:  #passes 27.0, function value: 0.5848903504172027
# dfSDCA_imp:  #passes 28.0, function value: 0.5848903500769038
# dfSDCA_imp:  #passes 29.0, function value: 0.5848903381470014
# dfSDCA_imp:  #passes 30.0, function value: 0.5848903299459959
# dfSDCA_imp:  #passes 31.0, function value: 0.5848903257460796
# dfSDCA_imp:  #passes 32.0, function value: 0.5848903243359169
# dfSDCA_imp:  #passes 33.0, function value: 0.584890321987766
# dfSDCA_imp:  #passes 34.0, function value: 0.58489032153171
# dfSDCA_imp:  #passes 35.0, function value: 0.5848903200849062
# dfSDCA_imp:  #passes 36.0, function value: 0.5848903198347422
# dfSDCA_imp:  #passes 37.0, function value: 0.5848903178945383
# dfSDCA_imp:  #passes 38.0, function value: 0.5848903175888354
# dfSDCA_imp:  #passes 39.0, function value: 0.5848903175202937
# dfSDCA_imp:  #passes 40.0, function value: 0.5848903174921705
# dfSDCA_imp:  #passes 41.0, function value: 0.5848903174865213
# dfSDCA_imp:  #passes 42.0, function value: 0.5848903174770503
# dfSDCA_imp:  #passes 43.0, function value: 0.5848903173456208
# dfSDCA_imp:  #passes 44.0, function value: 0.5848903172969055
# dfSDCA_imp:  #passes 45.0, function value: 0.5848903172966653
# dfSDCA_imp:  #passes 46.0, function value: 0.5848903172794354
# dfSDCA_imp:  #passes 47.0, function value: 0.5848903172762678
# dfSDCA_imp:  #passes 48.0, function value: 0.5848903172658544
# dfSDCA_imp:  #passes 49.0, function value: 0.5848903172627241
# dfSDCA_imp:  #passes 50.0, function value: 0.5848903172623203
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f2b2c0557d0>)
# dfSDCA_imp:  #passes 51.0, function value: 0.5848903172614396
# dfSDCA_imp:  #passes 52.0, function value: 0.5848903172609172
# dfSDCA_imp:  #passes 53.0, function value: 0.5848903172607945
# dfSDCA_imp:  #passes 54.0, function value: 0.5848903172607873
# dfSDCA_imp:  #passes 55.0, function value: 0.5848903172607732
# dfSDCA_imp:  #passes 56.0, function value: 0.5848903172607925
# dfSDCA_imp:  #passes 57.0, function value: 0.5848903172605903
# dfSDCA_imp:  #passes 58.0, function value: 0.5848903172605907
# dfSDCA_imp:  #passes 59.0, function value: 0.5848903172604965
# dfSDCA_imp:  #passes 60.0, function value: 0.5848903172604917
# dfSDCA_imp:  #passes 61.0, function value: 0.5848903172604744
# dfSDCA_imp:  #passes 62.0, function value: 0.5848903172604489
# dfSDCA_imp:  #passes 63.0, function value: 0.5848903172604454
# dfSDCA_imp:  #passes 64.0, function value: 0.5848903172604341
# dfSDCA_imp:  #passes 65.0, function value: 0.5848903172604355
# dfSDCA_imp:  #passes 66.0, function value: 0.5848903172604359
# dfSDCA_imp:  #passes 67.0, function value: 0.5848903172604363
# dfSDCA_imp:  #passes 68.0, function value: 0.5848903172604318
# dfSDCA_imp:  #passes 69.0, function value: 0.5848903172604295
# dfSDCA_imp:  #passes 70.0, function value: 0.5848903172604294
# dfSDCA_imp finished!

# %% [markdown]
# ### *Exercise F
#
# Does it make sense to update the probability vector $p$ throughout the iterations of dfSDCA? Can you come up with an adaptive strategy that leads to a faster method in runtime?
